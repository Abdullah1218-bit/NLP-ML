# %%
from sklearn.feature_extraction.text import TfidfVectorizer

# %%
corpus = [
    "Natural language processing is a field of AI",
    "Machine learning helps computers learn from data",
    "Deep learning is a part of machine learning"
]

# %%
tfidf_vectorizer = TfidfVectorizer()
tfidf_matrix = tfidf_vectorizer.fit_transform(corpus)
print(tfidf_vectorizer.get_feature_names_out())
print('\nArray :\n',tfidf_matrix.toarray())
# Out:
# ['ai' 'computers' 'data' 'deep' 'field' 'from' 'helps' 'is' 'language'
#  'learn' 'learning' 'machine' 'natural' 'of' 'part' 'processing']
#
# Array :
#  [[0.40301621 0.         0.         0.         0.40301621 0.
#   0.         0.30650422 0.40301621 0.         0.         0.
#   0.40301621 0.30650422 0.         0.40301621]
#  [0.         0.40301621 0.40301621 0.         0.         0.40301621
#   0.40301621 0.         0.         0.40301621 0.30650422 0.30650422
#   0.         0.         0.         0.        ]
#  [0.         0.         0.         0.40659827 0.         0.
#   0.         0.30922846 0.         0.         0.61845693 0.30922846
#   0.         0.30922846 0.40659827 0.        ]]
